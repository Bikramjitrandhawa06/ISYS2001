# %% [markdown]
# <a href="https://colab.research.google.com/github/Bikramjitrandhawa06/ISYS2001/blob/main/finance_tracker_profile_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Step 1 – State the Problem
#
# Goal:
# Create a simple Python program that sets up a user profile for a personal finance tracker. The program should ask the user for some basic details and then display a personalised welcome message using the information provided.
#
# Data to Gather:
#
# User’s name
#
# Preferred theme colour for the app
#
# Primary currency used for financial tracking
#
# One main savings goal

# %% [markdown]
# Step 2: Work the problem by hand
# example inputs:
# user_name = "Bikramjit Singh"
# theme_color = "dark"
# primary_currency = "AUD"
# main_savings_goal = "a holiday"
#
# Expected output:
#
# Welcome to your Personal Finance Tracker, Bikramjit Singh! Your profile is ready.
# The app will use a dark theme and all amounts will be in AUD.
# Let's start working towards your goal of saving for a holiday

# %% [markdown]
# Step 3– Develop an Algorithm (Pseudocode)
#
# 1.Start the program
#
# 2.Ask the user to enter their name
#
# 3.Ask the user for their preferred theme colour
#
# 4.Ask the user for their main currency
#
# 5.Ask the user for their main savings goal
#
# 6.Combine all the information into one welcome message
#
# 7.Print the message on the screen
#
# 8.End the program

# %%
# Finance Tracker Profile Setup (Step 4)

user_name = input("What is your name? ")
theme_color = input("What color would you like for your app theme? (e.g., blue, green, dark): ")
primary_currency = input("What is your primary currency? (e.g., AUD, USD, EUR): ")
main_savings_goal = input("What is one big savings goal you have? (e.g., New Car, Holiday): ")

summary = (
    "Welcome to your Personal Finance Tracker, " + user_name + "! Your profile is ready. "
    "The app will use a " + theme_color + " theme and all amounts will be in " + primary_currency + ". "
    "Let's start working towards your goal of saving for a " + main_savings_goal + "!"
)

print(summary)
# Out:
# What is your name? Bikramjit Singh
# What color would you like for your app theme? (e.g., blue, green, dark): dark
# What is your primary currency? (e.g., AUD, USD, EUR): AUD
# What is one big savings goal you have? (e.g., New Car, Holiday): Holiday
# Welcome to your Personal Finance Tracker, Bikramjit Singh! Your profile is ready. The app will use a dark theme and all amounts will be in AUD. Let's start working towards your goal of saving for a Holiday!

# %% [markdown]
# Step 5: Evidence Package (Lab Exit Ticket)

# %%
from datetime import datetime

evidence_package = {
    "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    "student_name": "Bikramjit Singh",
    "project_context": "This project involved creating a user profile setup for a personal finance tracker.",
    "ai_tool_used": "ChatGPT",
    "ai_assistance_summary": "I used AI to help organise my ideas and review my pseudocode before writing the final code.",
    "best_practice_reflection": "Using descriptive variable names made the program easier to read and understand.",
    "key_learning": "Planning the steps before writing the code made the program easier to complete."
}

print("="*50)
print("EVIDENCE PACKAGE SUBMISSION")
print("="*50)

for key, value in evidence_package.items():
    print(key + ":", value)

print("="*50)
# Out:
# ...
# EVIDENCE PACKAGE SUBMISSION
# ...
# timestamp: 2026-03-04 15:53:37
# student_name: Bikramjit Singh
# project_context: This project involved creating a user profile setup for a personal finance tracker.
# ai_tool_used: ChatGPT
# ai_assistance_summary: I used AI to help organise my ideas and review my pseudocode before writing the final code.
# best_practice_reflection: Using descriptive variable names made the program easier to read and understand.
# key_learning: Planning the steps before writing the code made the program easier to complete.
# ...

# %% [markdown]
# Reflection on Industry Best Practices
#
# How did descriptive variable names and comments improve your code?
#
# Using clear variable names made the program easier to understand and helped me remember what each variable was storing.
#
# Did you save your work frequently and use meaningful commit messages on GitHub?
#
# Yes, I saved my work regularly in Google Colab and uploaded the notebook to GitHub using a clear file name.
#
# How did documenting your thought process help?
#
# Writing down the problem, example inputs, and pseudocode helped me understand the logic before writing the code.

# %% [markdown]
# Final Reflection
#
# This project helped me understand how to plan a program before writing the code. By thinking about the problem, trying an example, and writing the steps first, it became easier to create the program. Using clear variable names also made the code easier to read. Overall, this activity helped me practise basic Python concepts like taking input from the user and printing a message.
#
# Next Steps
#
# In the future, I could improve this program by adding more inputs, such as another savings goal or more profile settings. I will also continue practising writing simple programs and organising my code clearly.
